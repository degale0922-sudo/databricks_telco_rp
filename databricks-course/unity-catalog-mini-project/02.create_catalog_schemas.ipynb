-- %% [markdown]
-- ###Crear Catalogs y Schemas para el Proyecto
-- 1. Catalog - telco_dev(sin Managed Location)
-- 2. Schemas - bronze, silver y gold(Con Managed Location)

-- %%
create catalog if not exists telco_dev;

-- %%
use catalog telco_dev;

-- %%
create schema if not exists bronze
managed location "abfss://bronze@sadatabricksextdegale.dfs.core.windows.net/"

-- %%
create schema if not exists silver
managed location "abfss://silver@sadatabricksextdegale.dfs.core.windows.net/"

-- %%
create schema if not exists gold
managed location "abfss://gold@sadatabricksextdegale.dfs.core.windows.net/"
