-- %% [markdown]
-- ###Crear External Location requeridas para el proyecto
-- 1. bronze
-- 2. silver
-- 3. gold

-- %%
create external location if not exists sadatabricksext_bronze
  URL 'abfss://bronze@sadatabricksextdegale.dfs.core.windows.net/'
  with(storage credential `databricks-ext-storage-credential`)

-- %%
describe external location sadatabricksext_bronze

-- %%
%fs
ls "abfss://bronze@sadatabricksextdegale.dfs.core.windows.net/"

-- %%
create external location if not exists sadatabricksext_silver
  URL 'abfss://silver@sadatabricksextdegale.dfs.core.windows.net/'
  with(storage credential `databricks-ext-storage-credential`)

-- %%
create external location if not exists sadatabricksext_gold
  URL 'abfss://gold@sadatabricksextdegale.dfs.core.windows.net/'
  with(storage credential `databricks-ext-storage-credential`)
